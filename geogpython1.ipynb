# %%
# Change directory to VSCode workspace root so that relative path loads work correctly. Turn this addition off with the DataScience.changeDirOnImportExport setting
import os
try:
	os.chdir(os.path.join(os.getcwd(), '..'))
	print(os.getcwd())
except:
	pass

# %%
## Task 13
def countdown(num):
    count = num
    while(count != 0):
        print("T-minus " + str(count))
        count-= 1
print(countdown(13))


## Task 14 
def quartile(num): 
    if(num <= 25):
        print("1st Quartile")
    elif(num > 25 and rando <= 50):
        print("2nd Quartile")
    elif(num > 50 and rando <= 75):
        print("3rd Quartile")
    elif(num > 75 and rando <= 100):
        print("4th Quartile")
    elif(num < 0 or num > 100)
        print("Error")
# Out:
#   File "<ipython-input-4-11c7ce7482cf>", line 21
#     elif(num < 0 or num > 100)
#                               ^
# SyntaxError: invalid syntax

# %%
## Task 13
def countdown(num):
    count = num
    while(count != 0):
        print("T-minus " + str(count))
        count-= 1
print(countdown(13))


## Task 14 
def quartile(num): 
    if(num <= 25):
        print("1st Quartile")
    elif(num > 25 and rando <= 50):
        print("2nd Quartile")
    elif(num > 50 and rando <= 75):
        print("3rd Quartile")
    elif(num > 75 and rando <= 100):
        print("4th Quartile")
    elif(num < 0 or num > 100):
        print("Error")
# Out:
# T-minus 13
# T-minus 12
# T-minus 11
# T-minus 10
# T-minus 9
# T-minus 8
# T-minus 7
# T-minus 6
# T-minus 5
# T-minus 4
# T-minus 3
# T-minus 2
# T-minus 1
# None

# %%
## Task 13
def countdown(num):
    count = num
    while(count != 0):
        print("T-minus " + str(count))
        count-= 1
print(countdown(15))


## Task 14 
def quartile(num): 
    if(num <= 25):
        print("1st Quartile")
    elif(num > 25 and rando <= 50):
        print("2nd Quartile")
    elif(num > 50 and rando <= 75):
        print("3rd Quartile")
    elif(num > 75 and rando <= 100):
        print("4th Quartile")
    elif(num < 0 or num > 100):
        print("Error")
# Out:
# T-minus 15
# T-minus 14
# T-minus 13
# T-minus 12
# T-minus 11
# T-minus 10
# T-minus 9
# T-minus 8
# T-minus 7
# T-minus 6
# T-minus 5
# T-minus 4
# T-minus 3
# T-minus 2
# T-minus 1
# None

# %%
## Task 11 
cities = ["Tacoma", "Seattle", "Bellevue", "Kent", "Redmond", "Mercer Island"]
for city in cities :
    print("Warning,residents of " + str(city) + ",temperatures will reach sub-zero temperatures today, please stay indoors if possible")

## Task 12 
empty = []
states = ["Washington", "California", "Nevada", "Idaho", "Montana", "Utah", "Colorado", "New Mexico"]
for state in states : 
    currentPath = "U://Users/Zhang/Geog_458/filename.shp".replace("filename", state)
    print(currentPath)

## Task 13
count = 10 
while(count != 0):
    print("T-minus " + str(count))
    count-= 1
# Out:
# Warning,residents of Tacoma,temperatures will reach sub-zero temperatures today, please stay indoors if possible
# Warning,residents of Seattle,temperatures will reach sub-zero temperatures today, please stay indoors if possible
# Warning,residents of Bellevue,temperatures will reach sub-zero temperatures today, please stay indoors if possible
# Warning,residents of Kent,temperatures will reach sub-zero temperatures today, please stay indoors if possible
# Warning,residents of Redmond,temperatures will reach sub-zero temperatures today, please stay indoors if possible
# Warning,residents of Mercer Island,temperatures will reach sub-zero temperatures today, please stay indoors if possible
# U://Users/Zhang/Geog_458/Washington.shp
# U://Users/Zhang/Geog_458/California.shp
# U://Users/Zhang/Geog_458/Nevada.shp
# U://Users/Zhang/Geog_458/Idaho.shp
# U://Users/Zhang/Geog_458/Montana.shp
# U://Users/Zhang/Geog_458/Utah.shp
# U://Users/Zhang/Geog_458/Colorado.shp
# ...

# %%
## Task 13
def countdown(num):
    count = num
    while(count != 0):
        print("T-minus " + str(count))
        count-= 1
countdown(15)


## Task 14 
def quartile(num): 
    if(num <= 25):
        print("1st Quartile")
    elif(num > 25 and rando <= 50):
        print("2nd Quartile")
    elif(num > 50 and rando <= 75):
        print("3rd Quartile")
    elif(num > 75 and rando <= 100):
        print("4th Quartile")
    elif(num < 0 or num > 100):
        print("Error")
# Out:
# T-minus 15
# T-minus 14
# T-minus 13
# T-minus 12
# T-minus 11
# T-minus 10
# T-minus 9
# T-minus 8
# T-minus 7
# T-minus 6
# T-minus 5
# T-minus 4
# T-minus 3
# T-minus 2
# T-minus 1

# %%
## Task 13
def countdown(num):
    count = num
    while(count != 0):
        print("T-minus " + str(count))
        count-= 1
countdown(15)


## Task 14 
def quartile(num): 
    if(num <= 25):
        print("1st Quartile")
    elif(num > 25 and rando <= 50):
        print("2nd Quartile")
    elif(num > 50 and rando <= 75):
        print("3rd Quartile")
    elif(num > 75 and rando <= 100):
        print("4th Quartile")
    elif(num < 0 or num > 100):
        print("Error")

quartile(13)
quartile(32)
quartile(86)
quartile(99)
quartile(-16)
quartile(213)
# Out:
# T-minus 15
# T-minus 14
# T-minus 13
# T-minus 12
# T-minus 11
# T-minus 10
# T-minus 9
# T-minus 8
# T-minus 7
# T-minus 6
# T-minus 5
# T-minus 4
# T-minus 3
# T-minus 2
# T-minus 1
# 1st Quartile
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-0d38b4eb96a5> in <module>()
#      23
#      24 quartile(13)
# ---> 25 quartile(32)
#      26 quartile(86)
#      27 quartile(99)
#
# <ipython-input-9-0d38b4eb96a5> in quartile(num)
#      13     if(num <= 25):
#      14         print("1st Quartile")
# ---> 15     elif(num > 25 and rando <= 50):
#      16         print("2nd Quartile")
#      17     elif(num > 50 and rando <= 75):
#
# NameError: name 'rando' is not defined

# %%
## Task 13
def countdown(num):
    count = num
    while(count != 0):
        print("T-minus " + str(count))
        count-= 1
countdown(15)


## Task 14 
def quartile(num): 
    if(num <= 25):
        print("1st Quartile")
    elif(num > 25 and num <= 50):
        print("2nd Quartile")
    elif(num > 50 and num <= 75):
        print("3rd Quartile")
    elif(num > 75 and num <= 100):
        print("4th Quartile")
    elif(num < 0 or num > 100):
        print("Error")

quartile(13)
quartile(32)
quartile(86)
quartile(99)
quartile(-16)
quartile(213)
# Out:
# T-minus 15
# T-minus 14
# T-minus 13
# T-minus 12
# T-minus 11
# T-minus 10
# T-minus 9
# T-minus 8
# T-minus 7
# T-minus 6
# T-minus 5
# T-minus 4
# T-minus 3
# T-minus 2
# T-minus 1
# 1st Quartile
# 2nd Quartile
# 4th Quartile
# 4th Quartile
# 1st Quartile
# Error

# %%
## Task 13
def countdown(num):
    count = num
    while(count != 0):
        print("T-minus " + str(count))
        count-= 1
countdown(15)


## Task 14 
def quartile(num): 
    if(num <= 25):
        print("1st Quartile")
    elif(num > 25 and num <= 50):
        print("2nd Quartile")
    elif(num > 50 and num <= 75):
        print("3rd Quartile")
    elif(num > 75 and num <= 100):
        print("4th Quartile")
    elif(num < 0 or num > 100):
        print("Error")

quartile(13)
quartile(32)
quartile(69)
quartile(95)
quartile(-16)
quartile(213)
# Out:
# T-minus 15
# T-minus 14
# T-minus 13
# T-minus 12
# T-minus 11
# T-minus 10
# T-minus 9
# T-minus 8
# T-minus 7
# T-minus 6
# T-minus 5
# T-minus 4
# T-minus 3
# T-minus 2
# T-minus 1
# 1st Quartile
# 2nd Quartile
# 3rd Quartile
# 4th Quartile
# 1st Quartile
# Error

# %%
## Task 10 
import random 
rando = random.randint(1,101)
print(rando)
if(rando >= 0 and rando <= 25):
    print("1st Quartile")
elif(rando > 25 and rando <= 50):
    print("2nd Quartile")
elif(rando > 50 and rando <= 75):
    print("3rd Quartile")
elif(rando > 75 and rando <= 100):
    print("4th Quartile")
# Out:
# 2
# 1st Quartile

# %%
## Task 10 
import random 
rando = random.randint(1,101)
print(rando)
if(rando >= 0 and rando <= 25):
    print("1st Quartile")
elif(rando > 25 and rando <= 50):
    print("2nd Quartile")
elif(rando > 50 and rando <= 75):
    print("3rd Quartile")
elif(rando > 75 and rando <= 100):
    print("4th Quartile")
# Out:
# 16
# 1st Quartile

# %%
## Task 13
def countdown(num):
    count = num
    while(count != 0):
        print("T-minus " + str(count))
        count-= 1
countdown(15)


## Task 14 
def quartile(num): 
    if(num >= 0 and num<= 25):
        print("1st Quartile")
    elif(num > 25 and num <= 50):
        print("2nd Quartile")
    elif(num > 50 and num <= 75):
        print("3rd Quartile")
    elif(num > 75 and num <= 100):
        print("4th Quartile")
    elif(num < 0 or num > 100):
        print("Error")

quartile(13)
quartile(32)
quartile(69)
quartile(95)
quartile(-16)
quartile(213)
# Out:
# T-minus 15
# T-minus 14
# T-minus 13
# T-minus 12
# T-minus 11
# T-minus 10
# T-minus 9
# T-minus 8
# T-minus 7
# T-minus 6
# T-minus 5
# T-minus 4
# T-minus 3
# T-minus 2
# T-minus 1
# 1st Quartile
# 2nd Quartile
# 3rd Quartile
# 4th Quartile
# Error
# Error

# %%
## Task 11 
cities = ["Tacoma", "Seattle", "Bellevue", "Kent", "Redmond", "Mercer Island"]
for city in cities :
    print("Warning,residents of " + str(city) + ",temperatures will reach sub-zero temperatures today, please stay indoors if possible")

## Task 12 
empty = []
states = ["Washington", "California", "Nevada", "Idaho", "Montana", "Utah", "Colorado", "New Mexico"]
for state in states : 
    currentPath = "U://Users/Zhang/Geog_458/filename.shp".replace("filename", state)
    empty.append(currentPath)
    print(currentPath)
print(empty)
## Task 13
count = 10 
while(count != 0):
    print("T-minus " + str(count))
    count-= 1
# Out:
# Warning,residents of Tacoma,temperatures will reach sub-zero temperatures today, please stay indoors if possible
# Warning,residents of Seattle,temperatures will reach sub-zero temperatures today, please stay indoors if possible
# Warning,residents of Bellevue,temperatures will reach sub-zero temperatures today, please stay indoors if possible
# Warning,residents of Kent,temperatures will reach sub-zero temperatures today, please stay indoors if possible
# Warning,residents of Redmond,temperatures will reach sub-zero temperatures today, please stay indoors if possible
# Warning,residents of Mercer Island,temperatures will reach sub-zero temperatures today, please stay indoors if possible
# U://Users/Zhang/Geog_458/Washington.shp
# U://Users/Zhang/Geog_458/California.shp
# U://Users/Zhang/Geog_458/Nevada.shp
# U://Users/Zhang/Geog_458/Idaho.shp
# U://Users/Zhang/Geog_458/Montana.shp
# U://Users/Zhang/Geog_458/Utah.shp
# U://Users/Zhang/Geog_458/Colorado.shp
# ...
